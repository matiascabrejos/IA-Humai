# %% [markdown]
# <a href="https://colab.research.google.com/github/matiascabrejos/IA-Humai/blob/main/exercise_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para este ejercicio vamos a importar un conjunto de datos con el listado de colegios públicos de Bogotá del año 2016

# %%
import pandas as pd

# %%
df_colegios = pd.read_csv('https://www.datos.gov.co/api/views/qijw-htwa/rows.csv?accessType=DOWNLOAD')

# %%
df_colegios.columns
df_colegios.shape
# Out:
# (2404, 30)

# %%
df_colegios.sample(5)
# Out:
#        año secretaria                              nombreestablecimiento  \
# 444   2016     BOGOTA  JARD INF CUNITAS Y CRAYOLAS                   ...
# 1406  2016     BOGOTA  INST JOSE MARTINEZ RUIZ                       ...
# 261   2016     BOGOTA  GIMN BOSQUES DEL NOGAL                        ...
# 75    2016     BOGOTA                      COLEGIO VENTIUN ANGELES (IED)
# 2122  2016     BOGOTA                COLEGIO REPUBLICA DEL ECUADOR (IED)
#
#         zona             direccion                       telefono  \
# 444   URBANA         KR 51 67 A 31            4815340 -- 2315307
# 1406  URBANA       CL 71 A 81 A 48                        5440499
# 261   URBANA       KR 130 132 A 72                        6905231
# 75    URBANA        KR 90 154 A 09  6838395 -- 6838616 -- 6838397
# 2122  URBANA  CL 7 A SUR 0 50 ESTE  2332566 -- 2469504 -- 2467236
#
#                       nombre_Rector   tipo_Establecimiento etnias  sector  \
# ...

# %%
colegios_filtro = df_colegios.loc[df_colegios['propiedad_Planta_Fisica'] == 'PERSONA NATURAL', :]

# %%
colegios_filtro
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# 5     2016     BOGOTA  COL SAN PATRICIO                              ...
# ...    ...        ...                                                ...
# 2395  2016     BOGOTA  LIC PEDAG CIENCIA Y CULTURA                   ...
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %%
colegios_filtro.shape
# Out:
# (1727, 30)
