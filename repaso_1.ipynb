# %% [markdown]
# <a href="https://colab.research.google.com/github/matiascabrejos/IA-Humai/blob/main/repaso_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2022-03-08/visualisations/listings.csv')

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871                            Comfortable double room   124245
# 4  29051                            Comfortable single room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Flip                  NaN                            Centrum-West
# 3      Edwin                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-Oost
#
#    latitude  longitude     room_type  price  minimum_nights  \
# ...

# %%
df.groupby('neighbourhood').aggregate({'price':['mean','median','size']})
# Out:
#                                              price
#                                               mean median size
# neighbourhood
# Bijlmer-Centrum                         116.135135  100.0   37
# Bijlmer-Oost                            129.600000  115.5   20
# Bos en Lommer                           138.799197  120.0  249
# Buitenveldert - Zuidas                  150.383562  115.0   73
# Centrum-Oost                            214.106732  160.0  609
# Centrum-West                            194.198606  153.0  861
# De Aker - Nieuw Sloten                  142.796875  100.0   64
# De Baarsjes - Oud-West                  179.692584  149.0  836
# De Pijp - Rivierenbuurt                 183.252220  159.0  563
# Gaasperdam - Driemond                   102.739130   85.0   46
# Geuzenveld - Slotermeer                 144.244898  119.0   98
# IJburg - Zeeburgereiland                175.226190  142.0  168
# Noord-Oost                              143.816000  119.0  125
# ...

# %%
df[df["neighbourhood"].str.contains("noord",case=False)]
# Out:
#             id                                              name    host_id  \
# 79      515088               Familyfriendly Suite incl breakfast    2536879
# 97      582382                             Amsterdam Family Home    2868026
# 103     613088               Your own cottage in the countryside    3040748
# 114     664697               Design Waterfront flat near station    1406783
# 115     667305               Green, sportive experience in A'dam    3375589
# ...        ...                                               ...        ...
# 5704  49611297          Modern chalet at 7 min from Amsterdam CS  276062491
# 5710  50359331  Luxe overnachten dichtbij Amsterdam en 't Twiske  406728648
# 5714  50957764              Rural fire cottage next to Amsterdam     913437
# 5718  52050333     Bed & Breakfast op mooiste plek van Waterland  405106044
# 5725  54290750        Beautifull waterfront villa near Amsterdam   24153892
#
# ...

# %%
df.query('price > 100').shape
# Out:
# (4233, 18)

# %%
df.query('price > 200').shape
# Out:
# (1381, 18)

# %%
df.query('price > 200 & neighbourhood == "Noord-Oost"')
# Out:
#             id                                               name    host_id  \
# 484    2667413                Family house on shores Amsterdam IJ    3042726
# 1548  13353566  Amsterdam City & Rural Life Combined. Free Par...   75415761
# 2623  23493489                    Amazing Dyke House in Amsterdam    9791621
# 3674  36163282  Spacious family dike house near city centre w/...   82235987
# 3838  38370765                                    Green Amsterdam    6785196
# 4214  42330275    Cozy apartment with private parking near center  336572860
# 4301  43495835        Captain Pippi; Amsterdam's finest Houseboat   53730026
# 4642  47469046  Ruime familiewoning voor gezin met kleine kind...     888543
# 4738  49052224  Big cosy house 3 min from metro &7 min city ce...    7933602
# 4744  49120098     Spacious house with great views near the city!    6478619
# 4941  50667689  Heerlijke luxe boot  Amsterdam @catamaran_blue...    7447481
# ...

# %%
df.query('price > 220 & neighbourhood == "Noord-Oost"').shape
# Out:
# (15, 18)

# %%
df.query('price > 300 & neighbourhood == "Noord-Oost"').shape
# Out:
# (7, 18)

# %%
df.query('price > 400 & neighbourhood == "Centrum-Oost"').shape
# Out:
# (33, 18)

# %%
df.query('price > 300 & neighbourhood == "De Pijp - Rivierenbuurt"').shape
# Out:
# (51, 18)

# %%
df.query('price > 300 & neighbourhood == "Buitenveldert - Zuidas"').shape
# Out:
# (4, 18)

# %%
df.query('price > 300 & neighbourhood == "Zuid" & room_type == "Private room"').shape
# Out:
# (3, 18)

# %%
df.query('price > 400 & neighbourhood == "Zuid"').shape
# Out:
# (17, 18)

# %%
df_fil = df.query('price > 220 & neighbourhood == "Noord-Oost"')

# %%
df_fil
# Out:
#             id                                               name    host_id  \
# 484    2667413                Family house on shores Amsterdam IJ    3042726
# 1548  13353566  Amsterdam City & Rural Life Combined. Free Par...   75415761
# 2623  23493489                    Amazing Dyke House in Amsterdam    9791621
# 3674  36163282  Spacious family dike house near city centre w/...   82235987
# 3838  38370765                                    Green Amsterdam    6785196
# 4214  42330275    Cozy apartment with private parking near center  336572860
# 4301  43495835        Captain Pippi; Amsterdam's finest Houseboat   53730026
# 4642  47469046  Ruime familiewoning voor gezin met kleine kind...     888543
# 4738  49052224  Big cosy house 3 min from metro &7 min city ce...    7933602
# 4744  49120098     Spacious house with great views near the city!    6478619
# 4941  50667689  Heerlijke luxe boot  Amsterdam @catamaran_blue...    7447481
# ...

# %%
df_filtwo = df.query('price > 220 & neighbourhood == "Noord-Oost" & host_name == "Lucas"')

# %%
df_filtwo
# Out:
#             id                                            name  host_id  \
# 4744  49120098  Spacious house with great views near the city!  6478619
#
#      host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 4744     Lucas                  NaN    Noord-Oost  52.39026    4.99454
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 4744  Entire home/apt    250               4                  3  2021-10-24
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 4744                0.3                               1                38
#
#       number_of_reviews_ltm                   license
# 4744                      3  0363 0B7D 4AA8 3306 3543

# %%
df_filtwo = df.query('price > 220 & neighbourhood == "Noord-Oost" & number_of_reviews	> 10')

# %%
df_filtwo
# Out:
#             id                                               name    host_id  \
# 484    2667413                Family house on shores Amsterdam IJ    3042726
# 1548  13353566  Amsterdam City & Rural Life Combined. Free Par...   75415761
# 4214  42330275    Cozy apartment with private parking near center  336572860
#
#      host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 484     Julius                  NaN    Noord-Oost  52.38517    4.95610
# 1548      Iris                  NaN    Noord-Oost  52.38531    4.95352
# 4214     Hesam                  NaN    Noord-Oost  52.39776    4.93731
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 484   Entire home/apt    239               5                 14  2020-08-12
# 1548     Private room    335               4                 19  2019-06-17
# 4214  Entire home/apt    240               3                 11  2021-11-14
#
# ...
